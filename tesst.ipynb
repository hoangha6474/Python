# %% [markdown]
# Day 2: Bạn là một giáo viên muốn quản lý điểm số của học sinh. Hãy viết một chương trình Python
# thực hiện các bước sau:
# • Khai báo biến:
#     – Tạo biến student_name (kiểu chuỗi) để lưu tên học sinh.
#     – Tạo hai biến math_score và science_score (kiểu số thực) để lưu điểm Toán và
# Khoa học của học sinh.
# • In thông tin ban đầu:
# – In ra thông tin học sinh theo hai cách khác nhau bằng hàm print:
# ∗ Cách 1: Dùng dấu + để nối chuỗi.
# ∗ Cách 2: Dùng f-string (Ví dụ: f"Tên: student_name").
# – Ví dụ output sẽ là:
# Tên: An, Điểm Toán: 8.5, Điểm Khoa học: 7.0
# Tên: An - Toán: 8.5 - Khoa học: 7.0
# • Tính toán với toán tử:
# – Tính và in ra:
# ∗ Tổng điểm: math_score + science_score.
# ∗ Hiệu điểm: math_score - science_score.
# ∗ Tích điểm: math_score * science_score.
# ∗ Thương điểm: math_score / science_score.
# – Ví dụ output:
# Tổng điểm: 15.5
# Hiệu điểm: 1.5
# Tích điểm: 59.5
# Thương điểm: 1.2142857142857142
# • Thay đổi giá trị: Giả sử học sinh được cộng thêm 1 điểm môn Toán vì làm bài tập
# tốt. Cập nhật giá trị math_score và in lại thông tin học sinh (dùng một trong hai cách
# ở bước 2).
# • Kiểm tra bằng if-else:
# – Tính điểm trung bình mới sau khi cập nhật.
# – Dùng if-elif-else để đánh giá.
# ∗ Nếu điểm trung bình >= 8.0: In "Xuất sắc".
# ∗ Nếu điểm trung bình >= 6.5: In "Khá".
# ∗ Nếu điểm trung bình >= 5.0: In "Trung bình".
# ∗ Còn lại: In "Cần cố gắng".
# – Ví dụ đầu ra (giả sử điểm trung bình là 8.25):
# "Xuất sắc".

# %%
#Khai bao bien
student_name = "Hoang"
math_score =
# Out:
#   Cell In[1], line 3
#     math_score =
#                  ^
# SyntaxError: invalid syntax
